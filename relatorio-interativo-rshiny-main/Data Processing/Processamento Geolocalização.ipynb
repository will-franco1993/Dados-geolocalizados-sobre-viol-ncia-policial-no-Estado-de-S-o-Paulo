# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../datasets/MDIP_2013_2021.csv", sep="$")

# %%
df['LONGITUDE'] = df['LONGITUDE'].apply(lambda x: str(x).replace(",", "."))
df['LATITUDE'] = df['LATITUDE'].apply(lambda x: str(x).replace(",", "."))

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
import time
import geopy
from tqdm import tqdm
geolocator = geopy.geocoders.ArcGIS()

end_encontradas = 0
end_nao_encontrados = 0

for i, v in tqdm(df.iterrows()):
    if v['LONGITUDE'] == 0.0 or v['LATITUDE'] == 0.0:
        if "DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS" in v['LOGRADOURO']:
            location = geolocator.geocode(f"{v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
            try:
                df.loc[i, 'LATITUDE'] = location.latitude
                df.loc[i, 'LONGITUDE'] = location.longitude
                time.sleep(1)
                end_encontradas += 1
            except Exception as e:
#                 print(f"Endereço não encontrado: {v['LOGRADOURO'].replace('S.', 'São ')}, {v['MUNICIPIO_CIRC'].replace('S.', 'São ')}-SP {e}" )
                df.drop([i])
                end_nao_encontrados += 1
        else:
            location = geolocator.geocode(f"{v['LOGRADOURO'].replace('S.', 'São ')}, {v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
            try:
                df.loc[i, 'LATITUDE'] = location.latitude
                df.loc[i, 'LONGITUDE'] = location.longitude
                time.sleep(1)
                end_encontradas += 1
            except Exception as e:
#                 print(f"Endereço não encontrado: {v['LOGRADOURO'].replace('S.', 'São ')}, {v['MUNICIPIO_CIRC'].replace('S.', 'São ')}-SP {e}" )
                try:
                    location = geolocator.geocode(f"{v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
                    df.loc[i, 'LATITUDE'] = location.latitude
                    df.loc[i, 'LONGITUDE'] = location.longitude
                    time.sleep(1)
                    end_nao_encontrados += 1
                except:
                    df = df.drop([i])
                    end_nao_encontrados += 1
    

    elif v['LONGITUDE'] == "na" or v['LONGITUDE'] == "nan" or v['LATITUDE'] == "na" or v['LATITUDE'] == "nan" :
        if "DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS" in v['LOGRADOURO']:
            location = geolocator.geocode(f"{v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
            try:
                df.loc[i, 'LATITUDE'] = location.latitude
                df.loc[i, 'LONGITUDE'] = location.longitude
                time.sleep(1)
                end_encontradas += 1
            except Exception as e:
#                 print(f"Endereço não encontrado: {v['LOGRADOURO'].replace('S.', 'São ')}, {v['MUNICIPIO_CIRC'].replace('S.', 'São ')}-SP {e}" )
                df = df.drop([i])
                end_nao_encontrados += 1
        else:
            location = geolocator.geocode(f"{v['LOGRADOURO'].replace('S.', 'São ')}, {v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
            try:
                df.loc[i, 'LATITUDE'] = location.latitude
                df.loc[i, 'LONGITUDE'] = location.longitude
                time.sleep(1)
                end_encontradas += 1
            except Exception as e:
#                 print(f"Endereço não encontrado: {v['LOGRADOURO'].replace('S.', 'São ')}, {v['MUNICIPIO_CIRC'].replace('S.', 'São ')}-SP {e}" )
                try:
                    location = geolocator.geocode(f"{v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
                    df.loc[i, 'LATITUDE'] = location.latitude
                    df.loc[i, 'LONGITUDE'] = location.longitude
                    time.sleep(1)
                    end_nao_encontrados += 1
                except:
                    df = df.drop([i])
                    end_nao_encontrados += 1
            

    elif is_number(v['LONGITUDE']):
        df.loc[i, 'LATITUDE'] = float(v['LATITUDE'])
        df.loc[i, 'LONGITUDE'] = float(v['LONGITUDE'])
    else:
        if "DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS" in v['LOGRADOURO']:
            location = geolocator.geocode(f"{v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
            try:
                df.loc[i, 'LATITUDE'] = location.latitude
                df.loc[i, 'LONGITUDE'] = location.longitude
                time.sleep(1)
                end_encontradas += 1
            except Exception as e:
#                 print(f"Endereço não encontrado: {v['LOGRADOURO'].replace('S.', 'São ')}, {v['MUNICIPIO_CIRC'].replace('S.', 'São ')}-SP {e}" )
                df = df.drop([i])
                end_nao_encontrados += 1
        else:
            location = geolocator.geocode(f"{v['LOGRADOURO'].replace('S.', 'São ')}, {v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
            try:
                df.loc[i, 'LATITUDE'] = float(location.latitude)
                df.loc[i, 'LONGITUDE'] = float(location.longitude)

                time.sleep(1)
                end_encontradas += 1
            except Exception as e:
#                 print(f"Endereço não encontrado: {v['LOGRADOURO'].replace('S.', 'São ')}, {v['MUNICIPIO_CIRC'].replace('S.', 'São ')}-SP, {e}")
                try:
                    location = geolocator.geocode(f"{v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
                    df.loc[i, 'LATITUDE'] = location.latitude
                    df.loc[i, 'LONGITUDE'] = location.longitude
                    time.sleep(1)
                    end_nao_encontrados += 1
                except:
                    df = df.drop([i])
                    end_nao_encontrados += 1

print(f"Endereços Encontrados: {end_encontradas}; Endereços não encontrados {end_nao_encontrados};")
# Out:
# 6896it [22:37,  5.08it/s]
# Endereços Encontrados: 1139; Endereços não encontrados 0;

# %%
for i, v in tqdm(df.iterrows()):
    if v['LATITUDE'] == 0 or v['LATITUDE'] == 0.0 or v['LONGITUDE'] == 0 or v['LONGITUDE'] == 0.0:
        if "DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS" in v['LOGRADOURO']:
            location = geolocator.geocode(f"{v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
            try:
                df.loc[i, 'LATITUDE'] = location.latitude
                df.loc[i, 'LONGITUDE'] = location.longitude
                time.sleep(1)
                end_encontradas += 1
            except Exception as e:
#                 print(f"Endereço não encontrado: {v['LOGRADOURO'].replace('S.', 'São ')}, {v['MUNICIPIO_CIRC'].replace('S.', 'São ')}-SP {e}" )
                df.drop([i])
                end_nao_encontrados += 1
        else:
            location = geolocator.geocode(f"{v['LOGRADOURO'].replace('S.', 'São ')}, {v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
            time.sleep(1)
            try:
                df.loc[i, 'LATITUDE'] = location.latitude
                df.loc[i, 'LONGITUDE'] = location.longitude
                end_encontradas += 1
            except Exception as e:
#                 print(f"Endereço não encontrado: {v['LOGRADOURO'].replace('S.', 'São ')}, {v['MUNICIPIO_CIRC'].replace('S.', 'São ')}-SP {e}" )
                try:
                    location = geolocator.geocode(f"{v['CIDADE_ELABORACAO'].replace('S.', 'São ')}-SP, Brazil")
                    df.loc[i, 'LATITUDE'] = location.latitude
                    df.loc[i, 'LONGITUDE'] = location.longitude
                    time.sleep(1)
                    end_nao_encontrados += 1
                except:
                    df = df.drop([i])
                    end_nao_encontrados += 1
# Out:
# 6896it [11:56,  9.63it/s]

# %%
df
# Out:
#      CIDADE_ELABORACAO                    SEC_ELABORACAO      DEP_ELABORACAO  \
# 0              S.PAULO  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP
# 1              S.PAULO  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP
# 2              S.PAULO  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP
# 3                BAURU                     DEL.SEC.BAURU   DEINTER 4 - BAURU
# 4              S.PAULO  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP
# ...                ...                               ...                 ...
# 6891           S.PAULO  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP
# 6892           S.PAULO  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP
# 6893           S.PAULO  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP
# 6894         S.VICENTE              DEL.SEC.PRAIA GRANDE  DEINTER 6 - SANTOS
# 6895           S.PAULO  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP
#
#      NUM_BO  ANO_BO   DATA_FATO dia mês   ano  MÊS OCOR  ...  DESCR_TIPOLOCAL  \
# 0         2    2013  01/01/2013   1   1  2013         1  ...      Via pública
# 1         4    2013  01/01/2013   1   1  2013         1  ...       Residência
# 2         6    2013  02/01/2013   2   1  2013         1  ...       Residência
# 3         9    2013  30/01/2013  30   1  2013         1  ...      Via pública
# 4         9    2013  03/01/2013   3   1  2013         1  ...      Via pública
# ...     ...     ...         ...  ..  ..   ...       ...  ...              ...
# 6891    238    2021  29/05/2021  29   5  2021         5  ...      Via pública
# 6892    237    2021  28/05/2021  28   5  2021         5  ...      Via pública
# 6893    236    2021  28/05/2021  28   5  2021         5  ...      Via pública
# 6894   1120    2021  31/05/2021  31   5  2021         5  ...      Via pública
# 6895    239    2021  31/05/2021  31   5  2021         5  ...      Via pública
#
#                                          LOGRADOURO NUMERO_LOGRADOURO  \
# 0                                    R LUIS MATHEUS                 1
# 1     DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS                NaN
# 2     DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS                NaN
# 3                                    R SANTA AGUEDA                96
# 4                             R ORMINDA PINTO VIELA                 6
# ...                                             ...               ...
# 6891                          AVENIDA FIM DE SEMANA               240
# 6892                                RUA DOS TRILHOS               100
# 6893              RUA PROFESSOR ANTONIO MARIA MOURA               118
# 6894                                 AVENIDA BRASIL               315
# 6895                          RUA ATTILIO BARTALINI                 2
#
#      LATITUDE LONGITUDE                                          NATUREZAS  \
# 0    -23.5427  -46.4249                       Homicídio simples (art. 121)
# 1    -23.5629  -46.6547                             Resistência (art. 329)
# 2    -23.5629  -46.6547                                    Ato Infracional
# 3    -22.3137  -49.0317                       Homicídio simples (art. 121)
# 4    -23.5252  -46.4042                             Resistência (art. 329)
# ...       ...       ...                                                ...
# 6891 -23.6548  -46.7474  Resistência (art. 329), Homicídio simples (art...
# 6892 -23.5524  -46.6092                       Homicídio simples (art. 121)
# 6893 -23.6697  -46.7428                       Homicídio simples (art. 121)
# 6894 -23.9656  -46.4134  Homicídio simples (art. 121), Localização/Apre...
# 6895 -23.6075  -46.5817  Resistência (art. 329), Disparo de arma de fog...
#
#       CONDUTA                                      DESDOBRAMENTO  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# ...       ...                                                ...
# 6891   OUTROS  §2o.Se a violência ou grave ameaça é exercida ...
# 6892      NaN  Lesão corporal decorrente de intervenção polic...
# 6893  VEICULO  §2o.Se a violência ou grave ameaça é exercida ...
# 6894      NaN  Art. 329 - Opor-se à execução de ato legal, me...
# 6895      NaN  Lesão corporal decorrente de intervenção polic...
#
#      FLAG_VITIMA_FATAL DATAHORA_REGISTRO_BO
# 0                  Sim           01/01/2013
# 1                  Sim           01/01/2013
# 2                  Sim           02/01/2013
# 3                  Sim           31/01/2013
# 4                  Sim           03/01/2013
# ...                ...                  ...
# 6891               Sim           29/05/2021
# 6892               Sim           29/05/2021
# 6893               Sim           29/05/2021
# 6894               Sim           31/05/2021
# 6895               Sim           31/05/2021
#
# [6896 rows x 36 columns]

# %%
df['CIDADE_ELABORACAO'] = df['CIDADE_ELABORACAO'].apply(lambda x: x.replace("SÃO ", "S.").replace("SAO ", "S.").replace("S.ANDRE", "SANTO ANDRE").replace("MOGI DAS", "MOJI DAS").replace("S.CRUZ DA CONCEICAO", "SANTA CRUZ DA CONCEICAO"))

# %%
df['COR'] = df['COR'].apply(lambda x: x.lstrip().rstrip())

# %%
df.to_csv("../datasets/formated_MPID.csv", sep="\t")

# %%
import pandas as pd
df = pd.read_csv("../datasets/formated_MPID.csv", sep="\t")

new_cor = []

for i in df['COR'].values:
    if i == "Outros":
        new_cor.append("NÃO INFORMADO")
    elif i == "Ignorada":
        new_cor.append("NÃO INFORMADO")
    elif i == "REGISTRADO NA PF":
        new_cor.append("NÃO INFORMADO")
    else:
        new_cor.append(i)
df["COR_FOMATADO"] = new_cor


new_gen = []

for i in df['SEXO_PESSOA'].values:
    if i == "Outros":
        new_gen.append("NÃO INFORMADO")
    elif i == "Ignorada":
        new_gen.append("NÃO INFORMADO")
    elif i == "REGISTRADO NA PF":
        new_gen.append("NÃO INFORMADO")
    else:
        new_gen.append(i)
df["SEXO_FOMATADO"] = new_gen
df = df.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'], axis=1)
df.to_csv("../datasets/formated_MPID.csv", sep="\t", )

# %%
df['HORA_FATO_HOUR_ONLY'] = [aux.split(":")[0] for aux in df['HORA_FATO'].values]

# %%
df.to_csv("../datasets/formated_MPID.csv", sep="\t")

# %%
df
# Out:
#       Unnamed: 0.1.1.1  Unnamed: 0.1.1.1.1 CIDADE_ELABORACAO  \
# 0                    0                   0           S.PAULO
# 1                    1                   1           S.PAULO
# 2                    2                   2           S.PAULO
# 3                    3                   3             BAURU
# 4                    4                   4           S.PAULO
# ...                ...                 ...               ...
# 6891              6891                6891           S.PAULO
# 6892              6892                6892           S.PAULO
# 6893              6893                6893           S.PAULO
# 6894              6894                6894         S.VICENTE
# 6895              6895                6895           S.PAULO
#
#                         SEC_ELABORACAO      DEP_ELABORACAO NUM_BO  ANO_BO  \
# 0     DHPP - DEP. HOM. PROTECAO PESSOA                DHPP      2    2013
# 1     DHPP - DEP. HOM. PROTECAO PESSOA                DHPP      4    2013
# 2     DHPP - DEP. HOM. PROTECAO PESSOA                DHPP      6    2013
# 3                        DEL.SEC.BAURU   DEINTER 4 - BAURU      9    2013
# 4     DHPP - DEP. HOM. PROTECAO PESSOA                DHPP      9    2013
# ...                                ...                 ...    ...     ...
# 6891  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP    238    2021
# 6892  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP    237    2021
# 6893  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP    236    2021
# 6894              DEL.SEC.PRAIA GRANDE  DEINTER 6 - SANTOS   1120    2021
# 6895  DHPP - DEP. HOM. PROTECAO PESSOA                DHPP    239    2021
#
#        DATA_FATO dia mês  ...   LATITUDE  LONGITUDE  \
# 0     01/01/2013   1   1  ... -23.542701 -46.424923
# 1     01/01/2013   1   1  ... -23.562870 -46.654680
# 2     02/01/2013   2   1  ... -23.562870 -46.654680
# 3     30/01/2013  30   1  ... -22.313722 -49.031686
# 4     03/01/2013   3   1  ... -23.525185 -46.404248
# ...          ...  ..  ..  ...        ...        ...
# 6891  29/05/2021  29   5  ... -23.654818 -46.747368
# 6892  28/05/2021  28   5  ... -23.552428 -46.609176
# 6893  28/05/2021  28   5  ... -23.669674 -46.742794
# 6894  31/05/2021  31   5  ... -23.965623 -46.413359
# 6895  31/05/2021  31   5  ... -23.607488 -46.581701
#
#                                               NATUREZAS  CONDUTA  \
# 0                          Homicídio simples (art. 121)      NaN
# 1                                Resistência (art. 329)      NaN
# 2                                       Ato Infracional      NaN
# 3                          Homicídio simples (art. 121)      NaN
# 4                                Resistência (art. 329)      NaN
# ...                                                 ...      ...
# 6891  Resistência (art. 329), Homicídio simples (art...   OUTROS
# 6892                       Homicídio simples (art. 121)      NaN
# 6893                       Homicídio simples (art. 121)  VEICULO
# 6894  Homicídio simples (art. 121), Localização/Apre...      NaN
# 6895  Resistência (art. 329), Disparo de arma de fog...      NaN
#
#                                           DESDOBRAMENTO FLAG_VITIMA_FATAL  \
# 0                                                   NaN               Sim
# 1                                                   NaN               Sim
# 2                                                   NaN               Sim
# 3                                                   NaN               Sim
# 4                                                   NaN               Sim
# ...                                                 ...               ...
# 6891  §2o.Se a violência ou grave ameaça é exercida ...               Sim
# 6892  Lesão corporal decorrente de intervenção polic...               Sim
# 6893  §2o.Se a violência ou grave ameaça é exercida ...               Sim
# 6894  Art. 329 - Opor-se à execução de ato legal, me...               Sim
# 6895  Lesão corporal decorrente de intervenção polic...               Sim
#
#      DATAHORA_REGISTRO_BO HORA_FATO_HOUR_ONLY COR_FOMATADO SEXO_FOMATADO
# 0              01/01/2013                  02       Branca     Masculino
# 1              01/01/2013                  18        Parda     Masculino
# 2              02/01/2013                  00       Branca     Masculino
# 3              31/01/2013                  22       Branca     Masculino
# 4              03/01/2013                  20        Parda     Masculino
# ...                   ...                 ...          ...           ...
# 6891           29/05/2021                  15        Parda     Masculino
# 6892           29/05/2021                  22        Parda     Masculino
# 6893           29/05/2021                  19        Preta     Masculino
# 6894           31/05/2021                  20        Parda     Masculino
# 6895           31/05/2021                  19       Branca     Masculino
#
# [6896 rows x 41 columns]
